# %%
import dpkt
import matplotlib.pyplot as plt
import socket

def extract_packet_lengths(pcap_file):
    packet_lengths = []
    packet_timestamps = []

    # Open the pcap file
    with open(pcap_file, 'rb') as file:
        # Create a pcap reader
        pcap = dpkt.pcap.Reader(file)
        count = 0
        # Iterate through each packet in the file
        for timestamp, packet in pcap:
            # Extract the length of the packet
            length = len(packet) - 66
            if count == 0:
                start_time = timestamp
            # Extract the source IP address from the Ethernet frame
            eth = dpkt.ethernet.Ethernet(packet)
            ip = eth.data
            src_ip = socket.inet_ntoa(ip.src)

            # Append the length and timestamp to the respective lists based on IP address
            if src_ip == '192.168.1.1':
                packet_lengths.append(length)
            elif src_ip == '192.168.1.10':
                packet_lengths.append(-length)

            packet_timestamps.append(timestamp-start_time)
            count +=1
    
    return packet_lengths, packet_timestamps

# Provide the path to your pcap file
pcap_file_path = '/Users/ct/Library/Mobile Documents/com~apple~CloudDocs/cybersecurity_robotics/presskey/capPressKey24.pcap'

# Extract packet lengths and timestamps
lengths, timestamps = extract_packet_lengths(pcap_file_path)

# Plot the positive and negative lengths separately using Matplotlib
fig, ax = plt.subplots(figsize=(10, 6)) # width: 10 inches, height: 6 inches
plt.bar(timestamps, lengths, 0.05)
plt.xlabel('Timestamp')
plt.ylabel('Packet Length')
plt.title('Packet Lengths over Time')
plt.savefig("Plots/PacketLengthTimePlot24.pdf")

plt.show()

# %%
import dpkt
import matplotlib.pyplot as plt
import socket

def extract_packet_lengths(pcap_file):
    packet_lengths = []
    packet_timestamps = []

    # Open the pcap file
    with open(pcap_file, 'rb') as file:
        # Create a pcap reader
        pcap = dpkt.pcap.Reader(file)
        count = 0
        # Iterate through each packet in the file
        for timestamp, packet in pcap:
            # Extract the length of the packet
            length = len(packet) - 66
            if count == 0:
                start_time = timestamp
            # Extract the source IP address from the Ethernet frame
            eth = dpkt.ethernet.Ethernet(packet)
            ip = eth.data
            src_ip = socket.inet_ntoa(ip.src)

            # Append the length and timestamp to the respective lists based on IP address
            if src_ip == '192.168.1.1':
                packet_lengths.append(length)
            elif src_ip == '192.168.1.10':
                packet_lengths.append(-length)

            packet_timestamps.append(timestamp-start_time)
            count +=1
    
    return packet_lengths, packet_timestamps

# Provide the path to your pcap file
pcap_file_path = '/Users/ct/Library/Mobile Documents/com~apple~CloudDocs/cybersecurity_robotics/presskey/capPressKey.pcap'

# Extract packet lengths and timestamps
lengths, timestamps = extract_packet_lengths(pcap_file_path)

# Plot the positive and negative lengths separately using Matplotlib
fig, ax = plt.subplots(figsize=(10, 6)) # width: 10 inches, height: 6 inches
plt.bar(timestamps, lengths, 0.05)
plt.xlabel('Timestamp')
plt.ylabel('Packet Length')
plt.title('Packet Lengths over Time')

plt.show()

# %%
import dpkt
import matplotlib.pyplot as plt
import socket

def extract_packet_lengths(pcap_file):
    packet_lengths = []
    packet_timestamps = []

    # Open the pcap file
    with open(pcap_file, 'rb') as file:
        # Create a pcap reader
        pcap = dpkt.pcap.Reader(file)
        count = 0
        # Iterate through each packet in the file
        for timestamp, packet in pcap:
            # Extract the length of the packet
            length = len(packet) - 66
            if count == 0:
                start_time = timestamp
            # Extract the source IP address from the Ethernet frame
            eth = dpkt.ethernet.Ethernet(packet)
            ip = eth.data
            src_ip = socket.inet_ntoa(ip.src)
            
            # Append the length and timestamp to the respective lists based on IP address
            if src_ip == '192.168.1.1':
                packet_lengths.append(length)
            elif src_ip == '192.168.1.10':
                packet_lengths.append(-length)
            
            packet_timestamps.append(timestamp-start_time)
            count +=1
    
    return packet_lengths, packet_timestamps

# Provide the path to your pcap file
pcap_file_path = '/Users/ct/Downloads/caps/capGripper1.pcap'

# Extract packet lengths and timestamps
lengths, timestamps = extract_packet_lengths(pcap_file_path)

# Plot the positive and negative lengths separately using Matplotlib
plt.plot(timestamps, lengths)
plt.xlabel('Timestamp')
plt.ylabel('Packet Length')
plt.title('Packet Lengths over Time')

plt.show()

# %%
import dpkt
import matplotlib.pyplot as plt
import socket

def extract_packet_lengths(pcap_file):
    packet_lengths = []
    packet_timestamps = []

    # Open the pcap file
    with open(pcap_file, 'rb') as file:
        # Create a pcap reader
        pcap = dpkt.pcap.Reader(file)
        count = 0
        # Iterate through each packet in the file
        for timestamp, packet in pcap:
            # Extract the length of the packet
            length = len(packet) - 66
            if count == 4:
                start_time = timestamp
            # Extract the source IP address from the Ethernet frame
            if count > 4 and count < 43:
                eth = dpkt.ethernet.Ethernet(packet)
                ip = eth.data
                src_ip = socket.inet_ntoa(ip.src)

                # Append the length and timestamp to the respective lists based on IP address
                if src_ip == '192.168.1.1':
                    packet_lengths.append(length)
                elif src_ip == '192.168.1.10':
                    packet_lengths.append(-length)

                packet_timestamps.append(timestamp-start_time)
            count +=1

    return packet_lengths, packet_timestamps

# Provide the path to your pcap file
pcap_file_path = '/Users/ct/Downloads/caps/capSeq3.pcap'

# Extract packet lengths and timestamps
lengths, timestamps = extract_packet_lengths(pcap_file_path)

# Plot the positive and negative lengths separately using Matplotlib
# plt.vlines(timestamps, ymin=0, ymax=lengths)
for i in range(len(lengths)):
    color = 'red' if lengths[i] < 0 else 'green'
    plt.vlines(timestamps, ymin=0, ymax=lengths, color=color)

plt.xlabel('Timestamp')
plt.ylabel('Packet Length')
plt.title('Packet Lengths over Time')

plt.show()

# %%
import dpkt
import matplotlib.pyplot as plt
import socket

def extract_packet_lengths(pcap_file):
    packet_lengths = []
    packet_timestamps = []

    # Open the pcap file
    with open(pcap_file, 'rb') as file:
        # Create a pcap reader
        pcap = dpkt.pcap.Reader(file)
        count = 0
        # Iterate through each packet in the file
        for timestamp, packet in pcap:
            # Extract the length of the packet
            length = len(packet) - 66
            if count == 4:
                start_time = timestamp
            # Extract the source IP address from the Ethernet frame
            if count > 4 and count < 43:
                eth = dpkt.ethernet.Ethernet(packet)
                ip = eth.data
                src_ip = socket.inet_ntoa(ip.src)

                # Append the length and timestamp to the respective lists based on IP address
                if src_ip == '192.168.1.1':
                    packet_lengths.append(length)
                elif src_ip == '192.168.1.10':
                    packet_lengths.append(-length)

                packet_timestamps.append(timestamp-start_time)
            count +=1

    return packet_lengths, packet_timestamps

# Provide the path to your pcap file
pcap_file_path = '/Users/ct/Downloads/caps/capSeq1.pcap'

# Extract packet lengths and timestamps
lengths, timestamps = extract_packet_lengths(pcap_file_path)

# Plot the positive and negative lengths separately using Matplotlib
# plt.vlines(timestamps, ymin=0, ymax=lengths)
for i in range(len(lengths)):
    color = 'red' if lengths[i] < 0 else 'green'
    plt.vlines(timestamps, ymin=0, ymax=lengths, color=color)

plt.xlabel('Timestamp')
plt.ylabel('Packet Length')
plt.title('Packet Lengths over Time')

plt.show()

# %%
import dpkt
import matplotlib.pyplot as plt
import socket

def extract_packet_lengths(pcap_file):
    packet_lengths = []
    packet_timestamps = []

    # Open the pcap file
    with open(pcap_file, 'rb') as file:
        # Create a pcap reader
        pcap = dpkt.pcap.Reader(file)
        count = 0
        # Iterate through each packet in the file
        for timestamp, packet in pcap:
            # Extract the length of the packet
            length = len(packet) - 66
            if count == 4:
                start_time = timestamp
            # Extract the source IP address from the Ethernet frame
            if count > 4 and count < 43:
                eth = dpkt.ethernet.Ethernet(packet)
                ip = eth.data
                src_ip = socket.inet_ntoa(ip.src)

                # Append the length and timestamp to the respective lists based on IP address
                if src_ip == '192.168.1.1':
                    packet_lengths.append(length)
                elif src_ip == '192.168.1.10':
                    packet_lengths.append(-length)

                packet_timestamps.append(timestamp-start_time)
            count +=1

    return packet_lengths, packet_timestamps

# Provide the path to your pcap file
pcap_file_path = '/Users/ct/Downloads/caps/capSeq2.pcap'

# Extract packet lengths and timestamps
lengths, timestamps = extract_packet_lengths(pcap_file_path)

# Plot the positive and negative lengths separately using Matplotlib
# plt.vlines(timestamps, ymin=0, ymax=lengths)
for i in range(len(lengths)):
    color = 'red' if lengths[i] < 0 else 'green'
    plt.vlines(timestamps, ymin=0, ymax=lengths, color=color)

plt.xlabel('Timestamp')
plt.ylabel('Packet Length')
plt.title('Packet Lengths over Time')

plt.show()

# %%
import dpkt
import matplotlib.pyplot as plt
import socket

def extract_packet_lengths(pcap_file):
    packet_lengths = []
    packet_timestamps = []

    # Open the pcap file
    with open(pcap_file, 'rb') as file:
        # Create a pcap reader
        pcap = dpkt.pcap.Reader(file)
        count = 0
        # Iterate through each packet in the file
        for timestamp, packet in pcap:
            # Extract the length of the packet
            length = len(packet) - 66
            if count == 4:
                start_time = timestamp
            # Extract the source IP address from the Ethernet frame
            if count > 4 and count < 30:
                eth = dpkt.ethernet.Ethernet(packet)
                ip = eth.data
                src_ip = socket.inet_ntoa(ip.src)

                # Append the length and timestamp to the respective lists based on IP address
                if src_ip == '192.168.1.1':
                    packet_lengths.append(length)
                elif src_ip == '192.168.1.10':
                    packet_lengths.append(-length)

                packet_timestamps.append(timestamp-start_time)
            count +=1

    return packet_lengths, packet_timestamps

# Provide the path to your pcap file
pcap_file_path = '/Users/ct/Downloads/caps/capCart1.pcap'

# Extract packet lengths and timestamps
lengths, timestamps = extract_packet_lengths(pcap_file_path)

# Plot the positive and negative lengths separately using Matplotlib
# plt.vlines(timestamps, ymin=0, ymax=lengths)
for i in range(len(lengths)):
    color = 'red' if lengths[i] < 0 else 'green'
    plt.vlines(timestamps, ymin=0, ymax=lengths, color=color)

plt.xlabel('Timestamp')
plt.ylabel('Packet Length')
plt.title('Packet Lengths over Time')

plt.show()

# %%
import dpkt
import matplotlib.pyplot as plt
import socket

def extract_packet_lengths(pcap_file):
    packet_lengths = []
    packet_timestamps = []

    # Open the pcap file
    with open(pcap_file, 'rb') as file:
        # Create a pcap reader
        pcap = dpkt.pcap.Reader(file)
        count = 0
        # Iterate through each packet in the file
        for timestamp, packet in pcap:
            # Extract the length of the packet
            length = len(packet) - 66
            if count == 4:
                start_time = timestamp
            # Extract the source IP address from the Ethernet frame
            if count > 4 and count < 30:
                eth = dpkt.ethernet.Ethernet(packet)
                ip = eth.data
                src_ip = socket.inet_ntoa(ip.src)

                # Append the length and timestamp to the respective lists based on IP address
                if src_ip == '192.168.1.1':
                    packet_lengths.append(length)
                elif src_ip == '192.168.1.10':
                    packet_lengths.append(-length)

                packet_timestamps.append(timestamp-start_time)
            count +=1

    return packet_lengths, packet_timestamps

# Provide the path to your pcap file
pcap_file_path = '/Users/ct/Downloads/caps/capCart2.pcap'

# Extract packet lengths and timestamps
lengths, timestamps = extract_packet_lengths(pcap_file_path)

# Plot the positive and negative lengths separately using Matplotlib
# plt.vlines(timestamps, ymin=0, ymax=lengths)
for i in range(len(lengths)):
    color = 'red' if lengths[i] < 0 else 'green'
    plt.vlines(timestamps, ymin=0, ymax=lengths, color=color)

plt.xlabel('Timestamp')
plt.ylabel('Packet Length')
plt.title('Packet Lengths over Time')

plt.show()

# %%
import dpkt
import matplotlib.pyplot as plt
import socket

def extract_packet_lengths(pcap_file):
    packet_lengths = []
    packet_timestamps = []

    # Open the pcap file
    with open(pcap_file, 'rb') as file:
        # Create a pcap reader
        pcap = dpkt.pcap.Reader(file)
        count = 0
        # Iterate through each packet in the file
        for timestamp, packet in pcap:
            # Extract the length of the packet
            length = len(packet) - 66
            if count == 4:
                start_time = timestamp
            # Extract the source IP address from the Ethernet frame
            if count > 4 and count < 36:
                eth = dpkt.ethernet.Ethernet(packet)
                ip = eth.data
                src_ip = socket.inet_ntoa(ip.src)

                # Append the length and timestamp to the respective lists based on IP address
                if src_ip == '192.168.1.1':
                    packet_lengths.append(length)
                elif src_ip == '192.168.1.10':
                    packet_lengths.append(-length)

                packet_timestamps.append(timestamp-start_time)
            count +=1

    return packet_lengths, packet_timestamps

# Provide the path to your pcap file
pcap_file_path = '/Users/ct/Downloads/caps/capAng1.pcap'

# Extract packet lengths and timestamps
lengths, timestamps = extract_packet_lengths(pcap_file_path)

# Plot the positive and negative lengths separately using Matplotlib
# plt.vlines(timestamps, ymin=0, ymax=lengths)
for i in range(len(lengths)):
    color = 'red' if lengths[i] < 0 else 'green'
    plt.vlines(timestamps, ymin=0, ymax=lengths, color=color)

plt.xlabel('Timestamp')
plt.ylabel('Packet Length')
plt.title('Packet Lengths over Time')

plt.show()

# %%
import dpkt
import matplotlib.pyplot as plt
import socket

def extract_packet_lengths(pcap_file):
    packet_lengths = []
    packet_timestamps = []

    # Open the pcap file
    with open(pcap_file, 'rb') as file:
        # Create a pcap reader
        pcap = dpkt.pcap.Reader(file)
        count = 0
        # Iterate through each packet in the file
        for timestamp, packet in pcap:
            # Extract the length of the packet
            length = len(packet) - 66
            if count == 4:
                start_time = timestamp
            # Extract the source IP address from the Ethernet frame
            if count > 4 and count < 42:
                eth = dpkt.ethernet.Ethernet(packet)
                ip = eth.data
                src_ip = socket.inet_ntoa(ip.src)

                # Append the length and timestamp to the respective lists based on IP address
                if src_ip == '192.168.1.1':
                    packet_lengths.append(length)
                elif src_ip == '192.168.1.10':
                    packet_lengths.append(-length)

                packet_timestamps.append(timestamp-start_time)
            count +=1

    return packet_lengths, packet_timestamps

# Provide the path to your pcap file
pcap_file_path = '/Users/ct/Downloads/caps/capAng2.pcap'

# Extract packet lengths and timestamps
lengths, timestamps = extract_packet_lengths(pcap_file_path)

# Plot the positive and negative lengths separately using Matplotlib
# plt.vlines(timestamps, ymin=0, ymax=lengths)
for i in range(len(lengths)):
    color = 'red' if lengths[i] < 0 else 'green'
    plt.vlines(timestamps, ymin=0, ymax=lengths, color=color)

plt.xlabel('Timestamp')
plt.ylabel('Packet Length')
plt.title('Packet Lengths over Time')

plt.show()

# %%
import dpkt
import matplotlib.pyplot as plt
import socket

def extract_packet_lengths(pcap_file):
    packet_lengths = []
    packet_timestamps = []

    # Open the pcap file
    with open(pcap_file, 'rb') as file:
        # Create a pcap reader
        pcap = dpkt.pcap.Reader(file)
        count = 0
        # Iterate through each packet in the file
        for timestamp, packet in pcap:
            # Extract the length of the packet
            length = len(packet) - 66
            if count == 4:
                start_time = timestamp
            # Extract the source IP address from the Ethernet frame
            if count > 4 and count < 33:
                eth = dpkt.ethernet.Ethernet(packet)
                ip = eth.data
                src_ip = socket.inet_ntoa(ip.src)

                # Append the length and timestamp to the respective lists based on IP address
                if src_ip == '192.168.1.1':
                    packet_lengths.append(length)
                elif src_ip == '192.168.1.10':
                    packet_lengths.append(-length)

                packet_timestamps.append(timestamp-start_time)
            count +=1

    return packet_lengths, packet_timestamps

# Provide the path to your pcap file
pcap_file_path = '/Users/ct/Downloads/caps/capAng3.pcap'

# Extract packet lengths and timestamps
lengths, timestamps = extract_packet_lengths(pcap_file_path)

# Plot the positive and negative lengths separately using Matplotlib
# plt.vlines(timestamps, ymin=0, ymax=lengths)
for i in range(len(lengths)):
    color = 'red' if lengths[i] < 0 else 'green'
    plt.vlines(timestamps, ymin=0, ymax=lengths, color=color)

plt.xlabel('Timestamp')
plt.ylabel('Packet Length')
plt.title('Packet Lengths over Time')

plt.show()

# %%
import dpkt
import matplotlib.pyplot as plt
import socket

def extract_packet_lengths(pcap_file):
    packet_lengths = []
    packet_timestamps = []

    # Open the pcap file
    with open(pcap_file, 'rb') as file:
        # Create a pcap reader
        pcap = dpkt.pcap.Reader(file)
        count = 0
        # Iterate through each packet in the file
        for timestamp, packet in pcap:
            # Extract the length of the packet
            length = len(packet) - 66
            if count == 4:
                start_time = timestamp
            # Extract the source IP address from the Ethernet frame
            if count > 275 and count < 295:
                eth = dpkt.ethernet.Ethernet(packet)
                ip = eth.data
                src_ip = socket.inet_ntoa(ip.src)

                # Append the length and timestamp to the respective lists based on IP address
                if src_ip == '192.168.1.1':
                    packet_lengths.append(length)
                elif src_ip == '192.168.1.10':
                    packet_lengths.append(-length)

                packet_timestamps.append(timestamp-start_time)
            count +=1

    return packet_lengths, packet_timestamps

# Provide the path to your pcap file
pcap_file_path = '/Users/ct/Downloads/caps/capPourWater.pcap'

# Extract packet lengths and timestamps
lengths, timestamps = extract_packet_lengths(pcap_file_path)

# Plot the positive and negative lengths separately using Matplotlib
# plt.vlines(timestamps, ymin=0, ymax=lengths)
for i in range(len(lengths)):
    color = 'red' if lengths[i] < 0 else 'green'
    plt.vlines(timestamps, ymin=0, ymax=lengths, color=color)

plt.xlabel('Timestamp')
plt.ylabel('Packet Length')
plt.title('Packet Lengths over Time')

plt.show()

# %%
import dpkt
import matplotlib.pyplot as plt
import socket

def extract_packet_lengths(pcap_file):
    packet_lengths = []
    packet_timestamps = []

    # Open the pcap file
    with open(pcap_file, 'rb') as file:
        # Create a pcap reader
        pcap = dpkt.pcap.Reader(file)
        count = 0
        # Iterate through each packet in the file
        for timestamp, packet in pcap:
            # Extract the length of the packet
            length = len(packet) - 66
            if count == 4:
                start_time = timestamp
            # Extract the source IP address from the Ethernet frame
            if count > 144 and count < 160:
                eth = dpkt.ethernet.Ethernet(packet)
                ip = eth.data
                src_ip = socket.inet_ntoa(ip.src)

                # Append the length and timestamp to the respective lists based on IP address
                if src_ip == '192.168.1.1':
                    packet_lengths.append(length)
                elif src_ip == '192.168.1.10':
                    packet_lengths.append(-length)

                packet_timestamps.append(timestamp-start_time)
            count +=1

    return packet_lengths, packet_timestamps

# Provide the path to your pcap file
pcap_file_path = '/Users/ct/Downloads/caps/capPourWater.pcap'

# Extract packet lengths and timestamps
lengths, timestamps = extract_packet_lengths(pcap_file_path)

# Plot the positive and negative lengths separately using Matplotlib
# plt.vlines(timestamps, ymin=0, ymax=lengths)
for i in range(len(lengths)):
    color = 'red' if lengths[i] < 0 else 'green'
    plt.vlines(timestamps, ymin=0, ymax=lengths, color=color)

plt.xlabel('Timestamp')
plt.ylabel('Packet Length')
plt.title('Packet Lengths over Time')

plt.show()

# %%
import dpkt
import matplotlib.pyplot as plt
import socket

def extract_packet_lengths(pcap_file):
    packet_lengths = []
    packet_timestamps = []

    # Open the pcap file
    with open(pcap_file, 'rb') as file:
        # Create a pcap reader
        pcap = dpkt.pcap.Reader(file)
        count = 0
        # Iterate through each packet in the file
        for timestamp, packet in pcap:
            # Extract the length of the packet
            length = len(packet) - 66
            if count == 4:
                start_time = timestamp
            # Extract the source IP address from the Ethernet frame
            if count > 250 and count < 350:
                eth = dpkt.ethernet.Ethernet(packet)
                ip = eth.data
                src_ip = socket.inet_ntoa(ip.src)

                # Append the length and timestamp to the respective lists based on IP address
                if src_ip == '192.168.1.1':
                    packet_lengths.append(length)
                elif src_ip == '192.168.1.10':
                    packet_lengths.append(-length)

                packet_timestamps.append(timestamp-start_time)
            count +=1

    return packet_lengths, packet_timestamps

# Provide the path to your pcap file
pcap_file_path = '/Users/ct/Downloads/caps/capGripper1.pcap'

# Extract packet lengths and timestamps
lengths, timestamps = extract_packet_lengths(pcap_file_path)

# Plot the positive and negative lengths separately using Matplotlib
# plt.vlines(timestamps, ymin=0, ymax=lengths)
for i in range(len(lengths)):
    color = 'red' if lengths[i] < 0 else 'green'
    plt.vlines(timestamps, ymin=0, ymax=lengths, color=color)

plt.xlabel('Timestamp')
plt.ylabel('Packet Length')
plt.title('Packet Lengths over Time')

plt.show()
